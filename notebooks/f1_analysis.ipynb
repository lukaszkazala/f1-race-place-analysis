# %%
import fastf1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys

sys.path.append("../")

from src.data_loader import (
    load_race_session,
    get_laps
)

session = load_race_session(
    2024,
    "Monza",
    "R"
)

laps = get_laps(session)

laps.head()
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '81', '4', '55', '44', '1', '63', '11', '23', '20', '14', '43', '3', '31', '10', '77', '27', '24', '18', '22']
# ...

# %%
from src.analysis import (
    get_best_laps,
    get_average_race_pace,
    get_driver_statistics
)

# %%
best_laps = get_best_laps(laps)

best_laps.head(10)
# Out:
# Driver
# NOR   0 days 00:01:21.432000
# HAM   0 days 00:01:21.512000
# VER   0 days 00:01:21.745000
# PIA   0 days 00:01:21.943000
# RUS   0 days 00:01:22.036000
# STR   0 days 00:01:22.232000
# ALO   0 days 00:01:22.944000
# PER   0 days 00:01:22.971000
# SAI   0 days 00:01:23.219000
# LEC   0 days 00:01:23.226000
# Name: LapTime, dtype: timedelta64[ns]

# %%
race_pace = get_average_race_pace(laps)

race_pace.head(10)
# Out:
# Driver
# PIA      0 days 00:01:23.542000
# NOR   0 days 00:01:23.607604166
# HAM   0 days 00:01:23.897270833
# LEC      0 days 00:01:23.949360
# RUS   0 days 00:01:23.983666666
# VER      0 days 00:01:24.124375
# SAI      0 days 00:01:24.236080
# PER   0 days 00:01:24.499208333
# ALO   0 days 00:01:24.687021276
# MAG   0 days 00:01:24.916877551
# Name: LapTime, dtype: timedelta64[ns]

# %%
stats = get_driver_statistics(laps)

stats.head(10)
# Out:
#                    mean_lap_time              lap_time_std  quick_lap_count
# Driver
# PIA       0 days 00:01:23.542000 0 days 00:00:00.951408273               48
# NOR    0 days 00:01:23.607604166 0 days 00:00:01.044424747               48
# HAM    0 days 00:01:23.897270833 0 days 00:00:01.183427059               48
# LEC       0 days 00:01:23.949360 0 days 00:00:00.629429374               50
# RUS    0 days 00:01:23.983666666 0 days 00:00:01.175278515               48
# VER       0 days 00:01:24.124375 0 days 00:00:01.121262977               48
# SAI       0 days 00:01:24.236080 0 days 00:00:00.783034933               50
# PER    0 days 00:01:24.499208333 0 days 00:00:01.013597237               48
# ALO    0 days 00:01:24.687021276 0 days 00:00:00.978855997               47
# MAG    0 days 00:01:24.916877551 0 days 00:00:00.850925247               49

# %%
from src.visualization import plot_race_pace

plot_race_pace(
    race_pace,
    save_path="../images/race_pace.png"
)

# %%
from src.visualization import plot_lap_time_evolution

plot_lap_time_evolution(
    laps,
    drivers=["PIA", "NOR", "LEC"],
    save_path="../images/lap_time_evolution.png"
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from src.visualization import plot_lap_time_evolution
#       3 plot_lap_time_evolution(
#       4     laps,
#       5     drivers=["PIA", "NOR", "LEC"],
#       6     save_path="../images/lap_time_evolution.png"
#       7 )
#
# ImportError: cannot import name 'plot_lap_time_evolution' from 'src.visualization' (d:\quant\f1-race-pace-analysis\notebooks\..\src\visualization.py)
